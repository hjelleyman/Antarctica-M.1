# %%
from modules import *

# %load_ext autoreload
# %autoreload 2

import matplotlib.pyplot as plt
import cartopy.crs as ccrs

import warnings
warnings.filterwarnings('ignore')

# %%
# Resolutions to save data as.
resolutions = [1]

# temporal averages
temporal_resolution = ['monthly', 'seasonal', 'annual']
temporal_resolution = ['annual']

# temporal_breakdown
temporal_decomposition = ['raw', 'anomalous']
temporal_decomposition = ['anomalous']

# detrending
# detrend = ['raw', 'detrended']
detrend = ['raw']
subindicies_list = [
                    ['SAM', 'meiv2', 'IPO', 'DMI'],
                    ['SAM', 'meiv2', '-IPO', 'DMI'],
                    ['SAM', 'SOI', 'IPO', 'DMI'],
                    ['SAM', 'nina12', 'IPO', 'DMI'],
                    ['SAM', 'nina34', 'IPO', 'DMI'],
                    ['SAM', 'IPO', 'DMI'],
                    ['SAM', 'IPO', 'DMI','nina34','nina12'],
                    ['SAM', 'IPO', 'DMI','nina34','SOI'],
                    ['nina34'],
                    ['SAM'],
                    ['IPO'],
                    ['DMI'],
                    ['nina12'],
                    ['SOI'],
                    ['meiv2'],
                   ]
p2.main_stacked(subindicies_list, resolutions, temporal_resolution,temporal_decomposition,detrend)
# Out:
# anomalous_annual_1_raw
# Finding coefficients
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████| 104912/104912 [00:04<00:00, 21161.34it/s]
# Predicting SIC
# findfont: Font family ['computer modern'] not found. Falling back to DejaVu Sans.
# anomalous_annual_1_raw
# Finding coefficients
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████| 104912/104912 [00:04<00:00, 21055.26it/s]
# Predicting SIC
# anomalous_annual_1_raw
# Finding coefficients
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████| 104912/104912 [00:05<00:00, 20979.91it/s]
# Predicting SIC
# anomalous_annual_1_raw
# Finding coefficients
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████| 104912/104912 [00:05<00:00, 20723.41it/s]
# Predicting SIC
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\IPython\core\interactiveshell.py", line 3417, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-2-9f57c8f284a3>", line 32, in <module>
#     p2.main_stacked(subindicies_list, resolutions, temporal_resolution,temporal_decomposition,detrend)
#   File "D:\Github Desktop\Antarctica-M.1\modules\plotting2.py", line 662, in main_stacked
#     main(subindicies, resolutions, temporal_resolution,temporal_decomposition,detrend)
#   File "D:\Github Desktop\Antarctica-M.1\modules\plotting2.py", line 657, in main
#     individual_contribution_to_trends(regression_results, normalized, sic)
#   File "D:\Github Desktop\Antarctica-M.1\modules\plotting2.py", line 539, in individual_contribution_to_trends
#     DATA = xr.Dataset(data).sortby('time').polyfit(dim='time', deg=1).sel(degree=1) * 1e9*60*60*24*365
#   File "C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\core\dataset.py", line 5987, in polyfit
#     coeffs, residuals = duck_array_ops.least_squares(
#   File "C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\core\duck_array_ops.py", line 625, in least_squares
#     return nputils.least_squares(lhs, rhs, rcond=rcond, skipna=skipna)
#   File "C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\core\nputils.py", line 239, in least_squares
#     out[:, nan_cols] = np.apply_along_axis(
#   File "<__array_function__ internals>", line 5, in apply_along_axis
#   File "C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\numpy\lib\shape_base.py", line 402, in apply_along_axis
#     buff[ind] = asanyarray(func1d(inarr_view[ind], *args, **kwargs))
#   File "C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\core\nputils.py", line 227, in _nanpolyfit_1d
#     out[:-1], out[-1], _, _ = np.linalg.lstsq(x[~mask, :], arr[~mask], rcond=rcond)
#   File "<__array_function__ internals>", line 5, in lstsq
#   File "C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\numpy\linalg\linalg.py", line 2327, in lstsq
#     x = x.astype(result_t, copy=True)  # Copying lets the memory in r_parts be freed
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\IPython\core\interactiveshell.py", line 2044, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'KeyboardInterrupt' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\IPython\core\ultratb.py", line 1169, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\IPython\core\ultratb.py", line 316, in wrapped
#     return f(*args, **kwargs)
#   File "C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\IPython\core\ultratb.py", line 350, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\inspect.py", line 1503, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\inspect.py", line 1461, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\inspect.py", line 708, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\inspect.py", line 754, in getmodule
#     os.path.realpath(f)] = module.__name__
#   File "C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\ntpath.py", line 647, in realpath
#     path = _getfinalpathname(path)
# KeyboardInterrupt
# Traceback (most recent call last):
#   File "C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\IPython\core\interactiveshell.py", line 3417, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-2-9f57c8f284a3>", line 32, in <module>
#     p2.main_stacked(subindicies_list, resolutions, temporal_resolution,temporal_decomposition,detrend)
#   File "D:\Github Desktop\Antarctica-M.1\modules\plotting2.py", line 662, in main_stacked
#     main(subindicies, resolutions, temporal_resolution,temporal_decomposition,detrend)
#   File "D:\Github Desktop\Antarctica-M.1\modules\plotting2.py", line 657, in main
#     individual_contribution_to_trends(regression_results, normalized, sic)
#   File "D:\Github Desktop\Antarctica-M.1\modules\plotting2.py", line 539, in individual_contribution_to_trends
#     DATA = xr.Dataset(data).sortby('time').polyfit(dim='time', deg=1).sel(degree=1) * 1e9*60*60*24*365
#   File "C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\core\dataset.py", line 5987, in polyfit
#     coeffs, residuals = duck_array_ops.least_squares(
#   File "C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\core\duck_array_ops.py", line 625, in least_squares
#     return nputils.least_squares(lhs, rhs, rcond=rcond, skipna=skipna)
#   File "C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\core\nputils.py", line 239, in least_squares
#     out[:, nan_cols] = np.apply_along_axis(
#   File "<__array_function__ internals>", line 5, in apply_along_axis
#   File "C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\numpy\lib\shape_base.py", line 402, in apply_along_axis
#     buff[ind] = asanyarray(func1d(inarr_view[ind], *args, **kwargs))
#   File "C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\core\nputils.py", line 227, in _nanpolyfit_1d
#     out[:-1], out[-1], _, _ = np.linalg.lstsq(x[~mask, :], arr[~mask], rcond=rcond)
#   File "<__array_function__ internals>", line 5, in lstsq
#   File "C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\numpy\linalg\linalg.py", line 2327, in lstsq
#     x = x.astype(result_t, copy=True)  # Copying lets the memory in r_parts be freed
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\IPython\core\interactiveshell.py", line 2044, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'KeyboardInterrupt' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\IPython\core\interactiveshell.py", line 3337, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\IPython\core\interactiveshell.py", line 3434, in run_code
#     self.showtraceback(running_compiled_code=True)
#   File "C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\IPython\core\interactiveshell.py", line 2046, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(etype,
#   File "C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\IPython\core\ultratb.py", line 1435, in structured_traceback
#     return FormattedTB.structured_traceback(
#   File "C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\IPython\core\ultratb.py", line 1335, in structured_traceback
#     return VerboseTB.structured_traceback(
#   File "C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\IPython\core\ultratb.py", line 1192, in structured_traceback
#     formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#   File "C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\IPython\core\ultratb.py", line 1150, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\IPython\core\ultratb.py", line 451, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\IPython\core\interactiveshell.py", line 2044, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\IPython\core\ultratb.py", line 1169, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\IPython\core\ultratb.py", line 316, in wrapped
#     return f(*args, **kwargs)
#   File "C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\IPython\core\ultratb.py", line 350, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\inspect.py", line 1503, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\inspect.py", line 1461, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\inspect.py", line 708, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\inspect.py", line 754, in getmodule
#     os.path.realpath(f)] = module.__name__
#   File "C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\ntpath.py", line 664, in realpath
#     if _getfinalpathname(spath) == path:
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# <ipython-input-2-9f57c8f284a3> in <module>
#      31                    ]
# ---> 32 p2.main_stacked(subindicies_list, resolutions, temporal_resolution,temporal_decomposition,detrend)
#
# D:\Github Desktop\Antarctica-M.1\modules\plotting2.py in main_stacked(subindicies_list, resolutions, temporal_resolution, temporal_decomposition, detrend)
#     661     for subindicies in subindicies_list:
# --> 662         main(subindicies, resolutions, temporal_resolution,temporal_decomposition,detrend)
#     663         # main2(subindicies, resolutions, temporal_resolution,temporal_decomposition,detrend)
#
# D:\Github Desktop\Antarctica-M.1\modules\plotting2.py in main(subindicies, resolutions, temporal_resolution, temporal_decomposition, detrend)
#     656     plt.style.use('stylesheets/contour.mplstyle')
# --> 657     individual_contribution_to_trends(regression_results, normalized, sic)
#     658
#
# D:\Github Desktop\Antarctica-M.1\modules\plotting2.py in individual_contribution_to_trends(regression_results, normalized, sic)
#     538
# --> 539     DATA = xr.Dataset(data).sortby('time').polyfit(dim='time', deg=1).sel(degree=1) * 1e9*60*60*24*365
#     540     if 'x' in DATA.dims:
#
# ~\Anaconda3\envs\Antarctica\lib\site-packages\xarray\core\dataset.py in polyfit(self, dim, deg, skipna, rcond, w, full, cov)
#    5986
# -> 5987             coeffs, residuals = duck_array_ops.least_squares(
#    5988                 lhs, rhs.data, rcond=rcond, skipna=skipna_da
#
# ~\Anaconda3\envs\Antarctica\lib\site-packages\xarray\core\duck_array_ops.py in least_squares(lhs, rhs, rcond, skipna)
#     624     else:
# --> 625         return nputils.least_squares(lhs, rhs, rcond=rcond, skipna=skipna)
#
# ~\Anaconda3\envs\Antarctica\lib\site-packages\xarray\core\nputils.py in least_squares(lhs, rhs, rcond, skipna)
#     238         if np.any(nan_cols):
# --> 239             out[:, nan_cols] = np.apply_along_axis(
#     240                 _nanpolyfit_1d, 0, rhs[:, nan_cols], lhs
#
# <__array_function__ internals> in apply_along_axis(*args, **kwargs)
#
# ~\Anaconda3\envs\Antarctica\lib\site-packages\numpy\lib\shape_base.py in apply_along_axis(func1d, axis, arr, *args, **kwargs)
#     401     for ind in inds:
# --> 402         buff[ind] = asanyarray(func1d(inarr_view[ind], *args, **kwargs))
#     403
#
# ~\Anaconda3\envs\Antarctica\lib\site-packages\xarray\core\nputils.py in _nanpolyfit_1d(arr, x, rcond)
#     226     if not np.all(mask):
# --> 227         out[:-1], out[-1], _, _ = np.linalg.lstsq(x[~mask, :], arr[~mask], rcond=rcond)
#     228     return out
#
# <__array_function__ internals> in lstsq(*args, **kwargs)
#
# ~\Anaconda3\envs\Antarctica\lib\site-packages\numpy\linalg\linalg.py in lstsq(a, b, rcond)
#    2326     resids = resids.astype(result_real_t, copy=False)
# -> 2327     x = x.astype(result_t, copy=True)  # Copying lets the memory in r_parts be freed
#    2328     return wrap(x), wrap(resids), rank, s
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# ~\Anaconda3\envs\Antarctica\lib\site-packages\IPython\core\interactiveshell.py in showtraceback(self, exc_tuple, filename, tb_offset, exception_only, running_compiled_code)
#    2043                         # in the engines. This should return a list of strings.
# -> 2044                         stb = value._render_traceback_()
#    2045                     except Exception:
#
# AttributeError: 'KeyboardInterrupt' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# ~\Anaconda3\envs\Antarctica\lib\site-packages\IPython\core\interactiveshell.py in run_ast_nodes(self, nodelist, cell_name, interactivity, compiler, result)
#    3336                         asy = compare(code)
# -> 3337                     if (await self.run_code(code, result,  async_=asy)):
#    3338                         return True
#
#     [... skipping hidden 1 frame]
#
# ~\Anaconda3\envs\Antarctica\lib\site-packages\IPython\core\interactiveshell.py in showtraceback(self, exc_tuple, filename, tb_offset, exception_only, running_compiled_code)
#    2045                     except Exception:
# -> 2046                         stb = self.InteractiveTB.structured_traceback(etype,
#    2047                                             value, tb, tb_offset=tb_offset)
#
# ~\Anaconda3\envs\Antarctica\lib\site-packages\IPython\core\ultratb.py in structured_traceback(self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1434             self.tb = tb
# -> 1435         return FormattedTB.structured_traceback(
#    1436             self, etype, value, tb, tb_offset, number_of_lines_of_context)
#
# ~\Anaconda3\envs\Antarctica\lib\site-packages\IPython\core\ultratb.py in structured_traceback(self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1334             # Verbose modes need a full traceback
# -> 1335             return VerboseTB.structured_traceback(
#    1336                 self, etype, value, tb, tb_offset, number_of_lines_of_context
#
# ~\Anaconda3\envs\Antarctica\lib\site-packages\IPython\core\ultratb.py in structured_traceback(self, etype, evalue, etb, tb_offset, number_of_lines_of_context)
#    1191
# -> 1192         formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#    1193                                                                tb_offset)
#
# ~\Anaconda3\envs\Antarctica\lib\site-packages\IPython\core\ultratb.py in format_exception_as_a_whole(self, etype, evalue, etb, number_of_lines_of_context, tb_offset)
#    1149
# -> 1150         last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#    1151
#
# ~\Anaconda3\envs\Antarctica\lib\site-packages\IPython\core\ultratb.py in find_recursion(etype, value, records)
#     450     if not is_recursion_error(etype, value, records):
# --> 451         return len(records), 0
#     452
#
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# ~\Anaconda3\envs\Antarctica\lib\site-packages\IPython\core\interactiveshell.py in showtraceback(self, exc_tuple, filename, tb_offset, exception_only, running_compiled_code)
#    2043                         # in the engines. This should return a list of strings.
# -> 2044                         stb = value._render_traceback_()
#    2045                     except Exception:
#
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# ~\Anaconda3\envs\Antarctica\lib\site-packages\IPython\core\async_helpers.py in _pseudo_sync_runner(coro)
#      66     """
#      67     try:
# ---> 68         coro.send(None)
#      69     except StopIteration as exc:
#      70         return exc.value
#
# ~\Anaconda3\envs\Antarctica\lib\site-packages\IPython\core\interactiveshell.py in run_cell_async(self, raw_cell, store_history, silent, shell_futures, transformed_cell, preprocessing_exc_tuple)
#    3143                     interactivity = 'async'
#    3144
# -> 3145                 has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#    3146                        interactivity=interactivity, compiler=compiler, result=result)
#    3147
#
# ~\Anaconda3\envs\Antarctica\lib\site-packages\IPython\core\interactiveshell.py in run_ast_nodes(self, nodelist, cell_name, interactivity, compiler, result)
#    3354             if result:
#    3355                 result.error_before_exec = sys.exc_info()[1]
# -> 3356             self.showtraceback()
#    3357             return True
#    3358
#
# ~\Anaconda3\envs\Antarctica\lib\site-packages\IPython\core\interactiveshell.py in showtraceback(self, exc_tuple, filename, tb_offset, exception_only, running_compiled_code)
#    2044                         stb = value._render_traceback_()
#    2045                     except Exception:
# -> 2046                         stb = self.InteractiveTB.structured_traceback(etype,
#    2047                                             value, tb, tb_offset=tb_offset)
#    2048
#
# ~\Anaconda3\envs\Antarctica\lib\site-packages\IPython\core\ultratb.py in structured_traceback(self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1433         else:
#    1434             self.tb = tb
# -> 1435         return FormattedTB.structured_traceback(
#    1436             self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1437
#
# ~\Anaconda3\envs\Antarctica\lib\site-packages\IPython\core\ultratb.py in structured_traceback(self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1333         if mode in self.verbose_modes:
#    1334             # Verbose modes need a full traceback
# -> 1335             return VerboseTB.structured_traceback(
#    1336                 self, etype, value, tb, tb_offset, number_of_lines_of_context
#    1337             )
#
# ~\Anaconda3\envs\Antarctica\lib\site-packages\IPython\core\ultratb.py in structured_traceback(self, etype, evalue, etb, tb_offset, number_of_lines_of_context)
#    1208         chained_exc_ids = set()
#    1209         while evalue:
# -> 1210             formatted_exceptions += self.format_exception_as_a_whole(etype, evalue, etb, lines_of_context,
#    1211                                                                      chained_exceptions_tb_offset)
#    1212             exception = self.get_parts_of_chained_exception(evalue)
#
# ~\Anaconda3\envs\Antarctica\lib\site-packages\IPython\core\ultratb.py in format_exception_as_a_whole(self, etype, evalue, etb, number_of_lines_of_context, tb_offset)
#    1148
#    1149
# -> 1150         last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#    1151
#    1152         frames = self.format_records(records, last_unique, recursion_repeat)
#
# ~\Anaconda3\envs\Antarctica\lib\site-packages\IPython\core\ultratb.py in find_recursion(etype, value, records)
#     449     # first frame (from in to out) that looks different.
#     450     if not is_recursion_error(etype, value, records):
# --> 451         return len(records), 0
#     452
#     453     # Select filename, lineno, func_name to track frames with
#
# TypeError: object of type 'NoneType' has no len()

# %% [markdown]
# Now we want to evaluate the different indicies and the fittings calculated above. For this we want the following evaluation stats.
#
#     1) Spatial correlation of trends.
#     2) Temporal correlation of SIE.
#     3) SIE Trend vs predicted.
#
# These will all be produced as tables but where possible I will include histograms for easy interpretation.

# %%
stats = p2.get_stats(subindicies_list, resolutions, temporal_resolution,temporal_decomposition,detrend)

# %%
stats
