# %% [markdown]
# # Plotting
#
# This notebook is used for plotting results after they've been comp.

# %%
from modules import *

# %load_ext autoreload
# %autoreload 2

import matplotlib.pyplot as plt

# %%
# What data to load
load_seaice   = True
load_indicies = True
load_ERA5     = False

# What indicies and variables
indicies  = ['SAM','IPO', 'DMI', 'ENSO']
variables = ['t2m']

# Resolutions to save data as.
resolutions = [1]
n = 5

# temporal averages
temporal_resolution = ['monthly', 'seasonal', 'annual']
temporal_resolution = ['seasonal', 'annual']

# temporal_breakdown
temporal_decomposition = ['raw', 'anomalous']

# detrending
detrend = ['raw', 'detrended']
detrend = ['raw']

seaice_source = 'nsidc'

minyear = 1979
maxyear = 2000
# Out:
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\ipykernel\ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %% [markdown]
# ## Time series

# %%
# Plot seaice time series
plt.style.use('stylesheets/timeseries.mplstyle')
plot.plot_all_seaice(resolutions, temporal_resolution, temporal_decomposition, detrend, seaice_source = seaice_source)
# Out:
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\ipykernel\ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}

# %%
# Plot index time series
plt.style.use('stylesheets/timeseries.mplstyle')
plot.plot_all_indicies(resolutions, temporal_resolution, temporal_decomposition, detrend, indicies = indicies)
# Out:
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\ipykernel\ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}

# %%
# Plot index time series with SIC
plt.style.use('stylesheets/timeseries.mplstyle')
plot.plot_all_indicies_sic(resolutions, temporal_resolution, temporal_decomposition, detrend, indicies, seaice_source = seaice_source)
# Out:
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\ipykernel\ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# findfont: Font family ['computer modern'] not found. Falling back to DejaVu Sans.
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}

# %%
# Plot seaice time series
plt.style.use('stylesheets/timeseries.mplstyle')
plot.plot_all_sic_sic(resolutions, temporal_resolution, temporal_decomposition, detrend)
# Out:
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\ipykernel\ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}

# %% [markdown]
# ## Correlations

# %%
plt.style.use('stylesheets/timeseries.mplstyle')
plot.plot_single_correlations(resolutions, temporal_resolution, temporal_decomposition, detrend, seaice_source = seaice_source)
# Out:
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\ipykernel\ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %% [markdown]
# We can also make the single correlations into a table which we will save in a format latex can read.

# %%
correlations, pvalues = plot.gen_single_correlation_table(resolutions, temporal_resolution, temporal_decomposition, detrend, seaice_source = seaice_source)
# Out:
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\ipykernel\ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
correlations
# Out:
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\ipykernel\ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#                           SAM        IPO        DMI       ENSO
# raw seasonal       -0.0474543 -0.0317001  0.0586973 -0.0125976
# anomalous seasonal   0.200599  -0.139697  0.0273798  0.0917371
# raw annual           0.275374  -0.139525  0.0220912   0.118458
# anomalous annual      0.28453  -0.164472  0.0226555   0.138644

# %%
pvalues
# Out:
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\ipykernel\ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#                           SAM        IPO       DMI      ENSO
# raw seasonal          0.55252   0.691611   0.47704   0.87477
# anomalous seasonal  0.0112344  0.0790483  0.740297  0.250119
# raw annual          0.0854657   0.390525  0.895264   0.46661
# anomalous annual    0.0751663   0.310509  0.892604  0.393556

# %%
plt.style.use('stylesheets/contour.mplstyle')
plot.plot_spatial_correlations(resolutions, temporal_resolution, temporal_decomposition, detrend, seaice_source=seaice_source)
# Out:
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\ipykernel\ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# <frozen importlib._bootstrap>:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 216, got 192
# <frozen importlib._bootstrap>:219: ImportWarning: can't resolve package from __spec__ or __package__, falling back on __name__ and __path__

# %%
plt.style.use('stylesheets/contour.mplstyle')
plot.plot_spatial_correlations_with_significance(resolutions, temporal_resolution, temporal_decomposition, detrend, seaice_source = seaice_source)
# Out:
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\ipykernel\ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %% [markdown]
# ## Regressions

# %%
plt.style.use('stylesheets/scatter.mplstyle')
plot.plot_all_regression_scatter(resolutions, temporal_resolution, temporal_decomposition, detrend, seaice_source = seaice_source)
# Out:
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\ipykernel\ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}

# %%
regressions, pvals, rvalues, bvalues, stderr = plot.gen_single_regression_table(resolutions, temporal_resolution, temporal_decomposition, detrend)
# Out:
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\ipykernel\ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
regressions
# Out:
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\ipykernel\ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#                         SAM      IPO      DMI     ENSO
# raw seasonal        -202416  -132150   266748 -52413.9
# anomalous seasonal  91121.5   -61996  13016.5  40622.7
# raw annual          97626.3 -47979.4  8418.68  41060.1
# anomalous annual     101394 -56843.3  8679.35  48305.2

# %%
pvals
# Out:
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\ipykernel\ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#                           SAM        IPO       DMI      ENSO
# raw seasonal          0.55252   0.691611   0.47704   0.87477
# anomalous seasonal  0.0112344  0.0790483  0.740297  0.250119
# raw annual          0.0854657   0.390525  0.895264   0.46661
# anomalous annual    0.0751663   0.310509  0.892604  0.393556

# %%
rvalues
# Out:
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\ipykernel\ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#                           SAM        IPO        DMI       ENSO
# raw seasonal       -0.0474543 -0.0317001  0.0586973 -0.0125976
# anomalous seasonal   0.200599  -0.139697  0.0273798  0.0917371
# raw annual           0.275374  -0.139525  0.0220912   0.118458
# anomalous annual      0.28453  -0.164472  0.0226555   0.138644

# %%
bvalues
# Out:
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\ipykernel\ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#                             SAM          IPO          DMI         ENSO
# raw seasonal        2.31059e+07  2.31019e+07  2.31337e+07  2.31022e+07
# anomalous seasonal     -3436.21     -1081.35      19467.6     -1922.16
# raw annual          2.30797e+07  2.30834e+07  2.30948e+07  2.30819e+07
# anomalous annual       -3679.35      202.248      11333.8     -1577.89

# %%
stderr
# Out:
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\ipykernel\ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#                         SAM      IPO      DMI     ENSO
# raw seasonal         340040   332535   374175   332026
# anomalous seasonal    35516    35071  39196.2  35191.6
# raw annual          55287.7  55238.3  63499.1  55833.6
# anomalous annual    55419.1  55301.9    63834    55974

# %% [markdown]
#  Plotting spatial maps

# %%
plt.style.use('stylesheets/contour.mplstyle')
plot.plot_all_regression_spatial(resolutions, temporal_resolution, temporal_decomposition, detrend)
# Out:
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\ipykernel\ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
plt.style.use('stylesheets/contour.mplstyle')
plot.plot_all_regression_multiple_spatial(resolutions, temporal_resolution, temporal_decomposition, detrend)
# Out:
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\ipykernel\ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
plt.style.use('stylesheets/contour.mplstyle')
plot.plot_all_regression_multiple_contribution_spatial_percentage(resolutions, temporal_resolution, temporal_decomposition, detrend=['raw'])
# Out:
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\ipykernel\ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}

# %% [markdown]
# # SIE Trends

# %%
plt.style.use('stylesheets/contour.mplstyle')
plot.plot_all_seaice_trends(resolutions, temporal_resolution, temporal_decomposition, detrend, seaice_source = seaice_source)
# Out:
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\ipykernel\ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}

# %%
plt.style.use('stylesheets/contour.mplstyle')
plot.plot_all_subplot_trends(resolutions, temporal_resolution, temporal_decomposition, detrend, seaice_source = seaice_source)
# Out:
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\ipykernel\ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}

# %%
plt.style.use('stylesheets/timeseries.mplstyle')
plot.predict_seaice(resolutions, temporal_resolution, temporal_decomposition, detrend, seaice_source = seaice_source)
# Out:
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\ipykernel\ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# ['SAM' 'IPO' 'DMI' 'ENSO' 'error']
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# ['SAM' 'IPO' 'DMI' 'ENSO' 'error']
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# ['SAM' 'IPO' 'DMI' 'ENSO' 'error']
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# ['SAM' 'IPO' 'DMI' 'ENSO' 'error']

# %% [markdown]
# # Percentage contributions

# %%
plt.style.use('stylesheets/contour.mplstyle')
plot.plot_all_regression_multiple_contribution_spatial_percentage(resolutions, temporal_resolution, temporal_decomposition, detrend=['raw'], mode = 'percentage')
# Out:
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\ipykernel\ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}

# %%
plt.style.use('stylesheets/timeseries.mplstyle')
plot.predict_seaice_components(resolutions, temporal_resolution, temporal_decomposition, detrend, seaice_source = seaice_source)
# Out:
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\ipykernel\ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}

# %%
plt.style.use('stylesheets/timeseries.mplstyle')
plot.predict_seaice_components_scatter(resolutions, temporal_resolution, temporal_decomposition, detrend, seaice_source = seaice_source)
# Out:
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\ipykernel\ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
# C:\Users\Hamish\Anaconda3\envs\Antarctica\lib\site-packages\xarray\backends\netCDF4_.py:372: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   attributes = {k: var.getncattr(k) for k in var.ncattrs()}
